# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# Select a sample image
image_path = "train/ffd078bbdb7c05e7.jpg"

# Load the image
image = cv2.imread(image_path)
if image is None:
    print(f"Image not found: {image_path}")
else:
    # Show original image
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title("Original Image")
    plt.axis('off')

    # Preprocessing: resize, grayscale, normalize
    resized = cv2.resize(image, (512, 512))
    gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
    normalized = gray / 255.0

    # Show preprocessed image
    plt.subplot(1, 2, 2)
    plt.imshow(normalized, cmap='gray')
    plt.title("Preprocessed Image")
    plt.axis('off')
    plt.show()

# %%
import pytesseract

# Perform OCR on the preprocessed grayscale image
ocr_result = pytesseract.image_to_string(gray)

print("Detected text:")
print(ocr_result)
# Out:
# Detected text:
# PRAHA Karlbv most a Hredtany
#
# CLECHOSLOVAK BROADCASTING CORPORATION
# Progue 12 Silinova 12
#
# Gesdoilontia Sep tomer 28956.
# DEAR RADIO FRIEND:
#
# op enkgtor your conmuseaion tSo2-Lemib ery
# _5 1959 _, reporting reception of our short wave
# 2.9) at )520__ GMT. We
# hove hcted yur dotbylog and ike lager
# epeteleabine Coney
# ‘We shall oppecito your frer repels os well
# cs suggetions ond css of oor programs. They
# help os in ranging fulre programs for you ond
# bringsits clsercotetihouroversostiends
# Thanking you again for your interes ond wishing you
# 00d reception in utr we oe,
#
# Ca" BEPuLAs Gi
#
# Gary R. Stevens
# 38 McCluskey sv
# iassena
# New York
#
# enue
#
# nana cRABA Mf Slalioora 12. CSR om
